# %%
import pandas as pd

# %%
df = pd.read_csv("IMDB Dataset 2.csv")

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)
